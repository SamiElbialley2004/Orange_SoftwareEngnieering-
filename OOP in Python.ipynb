# %%
class parrot:
  name=""
  age=0
parrot1=parrot()
parrot1.name="bli"
parrot1.age=10

print(f"{parrot1.name} is {parrot1.age} years old") #f is important here to said that the thing between {--} is value
# Out:
# bli is 10 years old

# %% [markdown]
# Constructore  __init__

# %%
class Employee:
   def __init__(self,name,age): #self like this
       self.name= name
       self.age= age

# %% [markdown]
# Inheritance

# %%
class Animal:
  def eat(self):
    print("i eat")
class Dog(Animal):
  def bark(self):
    print("I can bark woof woof")

dog1= Dog()
dog2 = Animal()
dog1.eat()
dog1.bark()
# Out:
# i eat
# I can bark woof woof

# %% [markdown]
# no constructors in python just use _init_

# %%
class Computer:

  def __init__(self):
     self._maxprice = 900
  def sell(self):
       print("selling price :{}".format(self._maxprice))
  def setMaxPrice(self , price):
       self._maxprice=price

c = Computer()
c.sell()
# Out:
# selling price :900

# %% [markdown]
# Polymaohism

# %%
class polygon
  def area(self)
       print("area of polygen ")
class square(polygon)
   def area(self)
         print("area of sqaure")

# %% [markdown]
# Lab2

# %%
class animals :
   def __init__(self,name):
      self.name=name
   def eat(self):
         print(f"the animal {self.name} eats")
   def sleep(self):
    print(f"the animal {self.name} sleep")


class cat(animals):
     def meow(self):
         print("I can meow, meow meow moew moew moew moew ")

class dog(animals):
        def bark(self):
         print("I can bark, woof woof")



dog1=dog("dog1")
cat1= cat("cat1")

dog1.eat()
cat1.eat()
dog1.bark()
cat1.meow()
# Out:
# the animal dog1 eats
# the animal cat1 eats
# I can bark, woof woof
# I can meow, meow meow moew moew moew moew
